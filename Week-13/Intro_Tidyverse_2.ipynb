# %% [markdown]
# # Introduction to `tidyverse` Round 2
# An ["opinionated" collection of R packages](https://tidyverse.org) for data science, driven by a coherent underlying design philosophy.
# These packages are meant to help you with two essential processes:
# 1. **Data clean-up and organization**: Structure should be intuitive, so that it's easy to model, manipulate, and think about the data
# 2. **Data plotting**: The grammar of graphics (Week 13)

# %%
library(tidyverse)

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Loading the data

# %%
data <- read_csv("data/148338_220209_095045_M057814.csv", skip=2)
# Out:
# Rows: 241 Columns: 32
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (21): type, stim1, stim2, stimPos, stimFormat, feedbackIncorrect, head, ...
# dbl (11): rowNo, ITI, feedbackTime, random, ITI_ms, ITI_f, ITI_fDuration, ti...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
education_level <- data %>% pull(response) %>% first()

data <- data %>%
    # Keep only useful columns
    select(c(rowNo, type, stim1, stim2, stimPos, trialType, response, RT)) %>%

    # Keep only useful rows
    filter(type != "form") %>%

    # Add demographic and trial-number info, turn trial type to factor
    mutate(
        education_level = education_level, # Add info
        trial_number = row_number(),
        trialType = factor(trialType, levels = c("incongruent", "congruent"))
    ) %>%

    # Rename trialType to trial_type
    rename(trial_type = trialType)

head(data)
# Out:
#   rowNo type stim1          stim2          stimPos       trial_type  response
# 1 190   test croissantLarge breadSmall     -341 0; 341 0 incongruent j
# 2 125   test lampSmall      shelfLarge     -235 0; 235 0 congruent   f
# 3 200   test schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j
# 4 152   test orangeLarge    raspberrySmall -307 0; 307 0 congruent   j
# 5 110   test hammerLarge    ladderSmall    -156 0; 156 0 incongruent j
# 6 215   test wheelSmall     coinLarge      -300 0; 300 0 incongruent f
#   RT   education_level             trial_number
# 1  729 College or Technical School 1
# 2  625 College or Technical School 2
# 3 1477 College or Technical School 3
# 4  793 College or Technical School 4
# 5  900 College or Technical School 5
# 6  699 College or Technical School 6

# %% [markdown]
# ### Tidying the data

# %% [markdown]
# Our data is almost tidy, but we still need to do several things.

# %% [markdown]
# #### Exercise 1
# There are two columns that are uninformative. Remove them.

# %%
# select(-c(...)) = to remove something
data <- data %>%
    select(-c(stimPos, education_level))
head(data)
# Out:
#   stim1          stim2          trial_type  response RT   trial_number
# 1 croissantLarge breadSmall     incongruent j         729 1
# 2 lampSmall      shelfLarge     congruent   f         625 2
# 3 schoolbusLarge bikeSmall      congruent   j        1477 3
# 4 orangeLarge    raspberrySmall congruent   j         793 4
# 5 hammerLarge    ladderSmall    incongruent j         900 5
# 6 wheelSmall     coinLarge      incongruent f         699 6

# %% [markdown]
# #### Exercise 2
# The columns `stim1` and `stim2` refer to the stimulus presented on the left and, respectively, right. Rename the columns to make them more informative.

# %%
# rename(new_name = old_name)
data <- data %>%
    rename(stim_left=stim1,stim_right=stim2)
head(data)
# Out:
#   stim_left      stim_right     trial_type  response RT   trial_number
# 1 croissantLarge breadSmall     incongruent j         729 1
# 2 lampSmall      shelfLarge     congruent   f         625 2
# 3 schoolbusLarge bikeSmall      congruent   j        1477 3
# 4 orangeLarge    raspberrySmall congruent   j         793 4
# 5 hammerLarge    ladderSmall    incongruent j         900 5
# 6 wheelSmall     coinLarge      incongruent f         699 6

# %% [markdown]
# #### Exercise 3
# Add a new column called `subject_id` and set this participant to 1.

# %%
# mutate(new_column = value) is to add something new
data <- data %>%
    mutate(subject_id = 1)
head(data)
# Out:
#   stim_left      stim_right     trial_type  response RT   trial_number
# 1 croissantLarge breadSmall     incongruent j         729 1
# 2 lampSmall      shelfLarge     congruent   f         625 2
# 3 schoolbusLarge bikeSmall      congruent   j        1477 3
# 4 orangeLarge    raspberrySmall congruent   j         793 4
# 5 hammerLarge    ladderSmall    incongruent j         900 5
# 6 wheelSmall     coinLarge      incongruent f         699 6
#   subject_id
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %% [markdown]
# #### Exercise 4
# Add a new column called `correct_side`. This column should encode the side of the correct answer (equivalently, the side of the smaller image). Use `str_detect(string, pattern)` to compute where the smaller image was on the screen and use a conditional `mutate` to fill in the values of `correct_side`.

# %%
# ifelse(condition, yes, no) = If the condition is satisfied, yes; otherwise, no.
data <- data %>%
    mutate(correct_side = ifelse(
        str_detect(stim_left, "Small"),
        "left",
        "right"
    ))
head(data)
# Out:
#   stim_left      stim_right     trial_type  response RT   trial_number
# 1 croissantLarge breadSmall     incongruent j         729 1
# 2 lampSmall      shelfLarge     congruent   f         625 2
# 3 schoolbusLarge bikeSmall      congruent   j        1477 3
# 4 orangeLarge    raspberrySmall congruent   j         793 4
# 5 hammerLarge    ladderSmall    incongruent j         900 5
# 6 wheelSmall     coinLarge      incongruent f         699 6
#   subject_id correct_side
# 1 1          right
# 2 1          left
# 3 1          right
# 4 1          right
# 5 1          right
# 6 1          left

# %% [markdown]
# #### Exercise 5
# Add a new column called `correct_key`. This column should be equal to `f` if the smaller image was on the left, and to `j` if the smaller image was on the right.

# %%
data <- data %>%
    mutate(correct_key = ifelse(
        correct_side == "left",
        "f",
        "j"
    ))
head(data)
# Out:
#   stim_left      stim_right     trial_type  response RT   trial_number
# 1 croissantLarge breadSmall     incongruent j         729 1
# 2 lampSmall      shelfLarge     congruent   f         625 2
# 3 schoolbusLarge bikeSmall      congruent   j        1477 3
# 4 orangeLarge    raspberrySmall congruent   j         793 4
# 5 hammerLarge    ladderSmall    incongruent j         900 5
# 6 wheelSmall     coinLarge      incongruent f         699 6
#   subject_id correct_side correct_key
# 1 1          right        j
# 2 1          left         f
# 3 1          right        j
# 4 1          right        j
# 5 1          right        j
# 6 1          left         f

# %% [markdown]
# #### Exercise 6
# Add a new column called `correct`. This column should be equal to 1 if the participant provided a correct response, 0 otherwise.

# %%
data <- data %>%
    mutate(correct = ifelse(
        response == correct_key,
        1,
        0
    ))
head(data)
# Out:
#   stim_left      stim_right     trial_type  response RT   trial_number
# 1 croissantLarge breadSmall     incongruent j         729 1
# 2 lampSmall      shelfLarge     congruent   f         625 2
# 3 schoolbusLarge bikeSmall      congruent   j        1477 3
# 4 orangeLarge    raspberrySmall congruent   j         793 4
# 5 hammerLarge    ladderSmall    incongruent j         900 5
# 6 wheelSmall     coinLarge      incongruent f         699 6
#   subject_id correct_side correct_key correct
# 1 1          right        j           1
# 2 1          left         f           1
# 3 1          right        j           1
# 4 1          right        j           1
# 5 1          right        j           1
# 6 1          left         f           1

# %% [markdown]
# #### Exercise 7
# The experiment had 240 trials, equally divided into two blocks. Add a new column called `trial_block` that encodes this.

# %%
data <- data %>%
    mutate(trial_block = ifelse(
        trial_number <= 120,
        1,
        2
    ))
head(data)
# Out:
#   stim_left      stim_right     trial_type  response RT   trial_number
# 1 croissantLarge breadSmall     incongruent j         729 1
# 2 lampSmall      shelfLarge     congruent   f         625 2
# 3 schoolbusLarge bikeSmall      congruent   j        1477 3
# 4 orangeLarge    raspberrySmall congruent   j         793 4
# 5 hammerLarge    ladderSmall    incongruent j         900 5
# 6 wheelSmall     coinLarge      incongruent f         699 6
#   subject_id correct_side correct_key correct trial_block
# 1 1          right        j           1       1
# 2 1          left         f           1       1
# 3 1          right        j           1       1
# 4 1          right        j           1       1
# 5 1          right        j           1       1
# 6 1          left         f           1       1

# %% [markdown]
# #### Exercise 8
# Recode `trial_number` so that it codes the trial number within a block. Instead of going from 1 to 240, it should go from 1 to 120 twice.

# %%
data <- data %>%
    mutate(trial_number = ((trial_number - 1) %% 120) + 1)
head(data)
# Out:
#   stim_left      stim_right     trial_type  response RT   trial_number
# 1 croissantLarge breadSmall     incongruent j         729 1
# 2 lampSmall      shelfLarge     congruent   f         625 2
# 3 schoolbusLarge bikeSmall      congruent   j        1477 3
# 4 orangeLarge    raspberrySmall congruent   j         793 4
# 5 hammerLarge    ladderSmall    incongruent j         900 5
# 6 wheelSmall     coinLarge      incongruent f         699 6
#   subject_id correct_side correct_key correct trial_block
# 1 1          right        j           1       1
# 2 1          left         f           1       1
# 3 1          right        j           1       1
# 4 1          right        j           1       1
# 5 1          right        j           1       1
# 6 1          left         f           1       1

# %% [markdown]
# #### Exercise 9
# It is good practice to use a consistent style throughout your script. One such style is called **snake**, the standard in python, which uses only lowercase letters and underscores: `variable_name`. Another common style is **camel**, the standard in JavaScript, which uses capital letters to mark the beginning of a new word: `variableName`. Our tibble at this point uses both styles, so turn all variable names to snake case. You can use `colnames` to see the vector of column names.

# %%
data <- data %>%
    rename(rt = RT)
head(data)
# Out:
#   stim_left      stim_right     trial_type  response rt   trial_number
# 1 croissantLarge breadSmall     incongruent j         729 1
# 2 lampSmall      shelfLarge     congruent   f         625 2
# 3 schoolbusLarge bikeSmall      congruent   j        1477 3
# 4 orangeLarge    raspberrySmall congruent   j         793 4
# 5 hammerLarge    ladderSmall    incongruent j         900 5
# 6 wheelSmall     coinLarge      incongruent f         699 6
#   subject_id correct_side correct_key correct trial_block
# 1 1          right        j           1       1
# 2 1          left         f           1       1
# 3 1          right        j           1       1
# 4 1          right        j           1       1
# 5 1          right        j           1       1
# 6 1          left         f           1       1

# %% [markdown]
# #### Exercise 10
# Using `select`, reorder the columns such that participant information comes first, followed by trial block and number, followed by trial info.

# %%
data <- data %>%
    select(
        subject_id,
        trial_block,
        trial_number,
        trial_type,
        stim_left,
        stim_right,
        correct_side,
        correct_key,
        response,
        correct,
        rt
    )
head(data)
# Out:
#   subject_id trial_block trial_number trial_type  stim_left      stim_right
# 1 1          1           1            incongruent croissantLarge breadSmall
# 2 1          1           2            congruent   lampSmall      shelfLarge
# 3 1          1           3            congruent   schoolbusLarge bikeSmall
# 4 1          1           4            congruent   orangeLarge    raspberrySmall
# 5 1          1           5            incongruent hammerLarge    ladderSmall
# 6 1          1           6            incongruent wheelSmall     coinLarge
#   correct_side correct_key response correct rt
# 1 right        j           j        1        729
# 2 left         f           f        1        625
# 3 right        j           j        1       1477
# 4 right        j           j        1        793
# 5 right        j           j        1        900
# 6 left         f           f        1        699

# %%
data %>% colnames()
# Out:
#  [1] "subject_id"   "trial_block"  "trial_number" "trial_type"   "stim_left"
#  [6] "stim_right"   "correct_side" "correct_key"  "response"     "correct"
# [11] "rt"

# %% [markdown]
# #### Exercise 11
# Concatenate all the commands in Exercises 1–10 into a single cell and store the output in a variable called `tidy_data`.

# %%
tidy_data <- data %>%
    # select(-c(...)) = to remove something
    select(-c(stimPos, education_level)) %>%

    # rename(new_name = old_name)
    rename(stim_left=stim1,stim_right=stim2) %>%

    # mutate(new_column = value) is to add something new
    mutate(subject_id = 1) %>%

    # ifelse(condition, yes, no) = If the condition is satisfied, yes; otherwise, no.
    mutate(correct_side = ifelse(
        str_detect(stim_left, "Small"),
        "left",
        "right"
    )) %>%


    mutate(correct_key = ifelse(
        correct_side == "left",
        "f",
        "j"
    )) %>%

    mutate(correct = ifelse(
        response == correct_key,
        1,
        0
    )) %>%

    mutate(trial_block = ifelse(
        trial_number <= 120,
        1,
        2
    )) %>%

    mutate(trial_number = ((trial_number - 1) %% 120) + 1) %>%

    rename(rt = RT) %>%

    select(
        subject_id,
        trial_block,
        trial_number,
        trial_type,
        stim_left,
        stim_right,
        correct_side,
        correct_key,
        response,
        correct,
        rt
    )
head(tidy_data)
# Out:
#   subject_id trial_block trial_number trial_type  stim_left      stim_right
# 1 1          1           1            incongruent croissantLarge breadSmall
# 2 1          1           2            congruent   lampSmall      shelfLarge
# 3 1          1           3            congruent   schoolbusLarge bikeSmall
# 4 1          1           4            congruent   orangeLarge    raspberrySmall
# 5 1          1           5            incongruent hammerLarge    ladderSmall
# 6 1          1           6            incongruent wheelSmall     coinLarge
#   correct_side correct_key response correct rt
# 1 right        j           j        1        729
# 2 left         f           f        1        625
# 3 right        j           j        1       1477
# 4 right        j           j        1        793
# 5 right        j           j        1        900
# 6 left         f           f        1        699

# %% [markdown]
# ### Summary statistics

# %%
tidy_data %>%
    summarize(rt = mean(rt), accuracy = mean(correct), error = mean(1 - correct))
# Out:
#   rt       accuracy  error
# 1 622.7542 0.9833333 0.01666667

# %%
tidy_data %>%
    mutate(avg_error = mean(1 - correct))
# Out:
#     subject_id trial_block trial_number trial_type  stim_left
# 1   1          1            1           incongruent croissantLarge
# 2   1          1            2           congruent   lampSmall
# 3   1          1            3           congruent   schoolbusLarge
# 4   1          1            4           congruent   orangeLarge
# 5   1          1            5           incongruent hammerLarge
# 6   1          1            6           incongruent wheelSmall
# 7   1          1            7           incongruent coconutSmall
# 8   1          1            8           congruent   pumpkinLarge
# 9   1          1            9           congruent   croissantSmall
# 10  1          1           10           incongruent trayLarge
# 11  1          1           11           congruent   lettuceLarge
# 12  1          1           12           incongruent cornSmall
# 13  1          1           13           congruent   chilliSmall
# 14  1          1           14           congruent   kittySmall
# 15  1          1           15           incongruent apricotLarge
# 16  1          1           16           incongruent cowSmall
# 17  1          1           17           incongruent cauliflowerSmall
# 18  1          1           18           congruent   duckSmall
# 19  1          1           19           congruent   wheelbarrowSmall
# 20  1          1           20           congruent   dishwasherLarge
# 21  1          1           21           congruent   chickenSmall
# 22  1          1           22           congruent   parrotSmall
# 23  1          1           23           congruent   airplaneLarge
# 24  1          1           24           incongruent deerSmall
# 25  1          1           25           incongruent giraffeSmall
# 26  1          1           26           incongruent dolphinSmall
# 27  1          1           27           congruent   tableLarge
# 28  1          1           28           congruent   beeSmall
# 29  1          1           29           congruent   graterSmall
# 30  1          1           30           incongruent donkeySmall
# ⋮   ⋮          ⋮           ⋮            ⋮           ⋮
# 211 1          2            91          incongruent orangutanSmall
# 212 1          2            92          incongruent pigeonLarge
# 213 1          2            93          congruent   squirrelSmall
# 214 1          2            94          incongruent pineappleSmall
# 215 1          2            95          incongruent lighterLarge
# 216 1          2            96          congruent   alligatorLarge
# 217 1          2            97          incongruent beltLarge
# 218 1          2            98          incongruent ovenSmall
# 219 1          2            99          incongruent oliveLarge
# 220 1          2           100          congruent   treeLarge
# 221 1          2           101          congruent   cannonLarge
# 222 1          2           102          congruent   ovenLarge
# 223 1          2           103          congruent   sheepLarge
# 224 1          2           104          congruent   backpackSmall
# 225 1          2           105          incongruent scissorsLarge
# 226 1          2           106          incongruent cannonSmall
# 227 1          2           107          congruent   plumSmall
# 228 1          2           108          incongruent lettuceSmall
# 229 1          2           109          incongruent tigerSmall
# 230 1          2           110          incongruent houseLarge
# 231 1          2           111          congruent   lizardSmall
# 232 1          2           112          congruent   butterflySmall
# 233 1          2           113          incongruent treeSmall
# 234 1          2           114          congruent   elephantLarge
# 235 1          2           115          incongruent gorillaSmall
# 236 1          2           116          incongruent schoolbusSmall
# 237 1          2           117          incongruent orangeSmall
# 238 1          2           118          congruent   helicopterLarge
# 239 1          2           119          congruent   scissorsSmall
# 240 1          2           120          congruent   oliveSmall
#     stim_right      correct_side correct_key response correct rt   avg_error
# 1   breadSmall      right        j           j        1        729 0.01666667
# 2   shelfLarge      left         f           f        1        625 0.01666667
# 3   bikeSmall       right        j           j        1       1477 0.01666667
# 4   raspberrySmall  right        j           j        1        793 0.01666667
# 5   ladderSmall     right        j           j        1        900 0.01666667
# 6   coinLarge       left         f           f        1        699 0.01666667
# 7   blueberryLarge  left         f           f        1        752 0.01666667
# 8   mushroomSmall   right        j           j        1        567 0.01666667
# 9   breadLarge      left         f           f        1        556 0.01666667
# 10  bedSmall        right        j           j        1        801 0.01666667
# 11  oliveSmall      right        j           j        1        564 0.01666667
# 12  green beanLarge left         f           f        1        597 0.01666667
# 13  eggplantLarge   left         f           f        1        534 0.01666667
# 14  donkeyLarge     left         f           f        1        436 0.01666667
# 15  watermelonSmall right        j           j        1        457 0.01666667
# 16  hedgehogLarge   left         f           f        1        481 0.01666667
# 17  onionLarge      left         f           f        1        480 0.01666667
# 18  zebraLarge      left         f           f        1        426 0.01666667
# 19  carLarge        left         f           f        1        437 0.01666667
# 20  backpackSmall   right        j           j        1        606 0.01666667
# 21  pandaLarge      left         f           f        1        460 0.01666667
# 22  orangutanLarge  left         f           f        1        454 0.01666667
# 23  skateboardSmall right        j           j        1        614 0.01666667
# 24  frogLarge       left         f           f        1        490 0.01666667
# 25  antLarge        left         f           f        1       1037 0.01666667
# 26  goldfishLarge   left         f           f        1        485 0.01666667
# 27  hairdryerSmall  right        j           j        1        493 0.01666667
# 28  sheepLarge      left         f           f        1        428 0.01666667
# 29  skyscraperLarge left         f           f        1        501 0.01666667
# 30  kittyLarge      left         f           f        1        990 0.01666667
# ⋮   ⋮               ⋮            ⋮           ⋮        ⋮       ⋮    ⋮
# 211 parrotLarge     left         f           f        1        808 0.01666667
# 212 camelSmall      right        j           j        1        957 0.01666667
# 213 gorillaLarge    left         f           f        1        540 0.01666667
# 214 cherryLarge     left         f           f        1        404 0.01666667
# 215 treeSmall       right        j           j        1        586 0.01666667
# 216 shrimpSmall     right        j           j        1        560 0.01666667
# 217 cannonSmall     right        j           j        1       1199 0.01666667
# 218 bootLarge       left         f           f        1        478 0.01666667
# 219 lettuceSmall    right        j           j        1       1407 0.01666667
# 220 lighterSmall    right        j           j        1        547 0.01666667
# 221 beltSmall       right        j           j        1        522 0.01666667
# 222 bootSmall       right        j           j        1        498 0.01666667
# 223 beeSmall        right        j           j        1        490 0.01666667
# 224 dishwasherLarge left         f           f        1        437 0.01666667
# 225 trunkSmall      right        j           j        1        727 0.01666667
# 226 beltLarge       left         f           f        1        523 0.01666667
# 227 melonLarge      left         f           f        1        447 0.01666667
# 228 oliveLarge      left         f           f        1        416 0.01666667
# 229 rabbitLarge     left         f           f        1        455 0.01666667
# 230 leafSmall       right        j           j        1        518 0.01666667
# 231 rhinoLarge      left         f           f        1        458 0.01666667
# 232 elephantLarge   left         f           f        1        433 0.01666667
# 233 lighterLarge    left         f           f        1        429 0.01666667
# 234 butterflySmall  right        j           j        1        476 0.01666667
# 235 squirrelLarge   left         f           f        1        456 0.01666667
# 236 bikeLarge       left         f           f        1        672 0.01666667
# 237 raspberryLarge  left         f           f        1        357 0.01666667
# 238 tricycleSmall   right        j           j        1        498 0.01666667
# 239 trunkLarge      left         f           f        1        697 0.01666667
# 240 lettuceLarge    left         f           f        1        414 0.01666667

# %% [markdown]
# #### Exercise 12
# Using the `.by` argument in the call to `summarize`, find out if our participant showed the predicted size Stroop in reaction times and error rates.

# %%
tidy_data %>%
    summarize(
        mean_rt = mean(rt),
        accuracy = mean(correct),
        error = mean(1 - correct),
        .by = trial_type
    )
# Participants showed a Stroop effect because they tend to make more mistakes when doing the incongruent task.
# Out:
#   trial_type  mean_rt  accuracy  error
# 1 incongruent 698.1000 0.9666667 0.03333333
# 2 congruent   547.4083 1.0000000 0.00000000

# %% [markdown]
# #### Exercise 13
# Using a similar logic, find out if our participant also showed a SNARC effect: Was the participant faster when the small image was on the left?

# %%
tidy_data %>%
    summarize(mean_rt = mean(rt), .by = correct_side)

# Yes, the participant was faster when the small image was on the left. The participant showed a SNARC effect.
# Out:
#   correct_side mean_rt
# 1 right        632.7333
# 2 left         612.7750

# %% [markdown]
# #### Exercise 14
# Find out if the SNARC effect depends on trial type.

# %%
tidy_data %>%
    summarize(mean_rt = mean(rt), .by = c(trial_type, correct_side))

# SNARC effect is obvious only in congruent trials, and this effect somehow was weaker in incongruent trials.
# Out:
#   trial_type  correct_side mean_rt
# 1 incongruent right        694.9167
# 2 congruent   left         524.2667
# 3 congruent   right        570.5500
# 4 incongruent left         701.2833

# %% [markdown]
# ## From a single participant to a full dataset
# We load all the 12 csv files in the 'data' folder, then apply the `read_csv` function to each of them using `map_dfr`. The `.id` argument creates a column that keeps the information from each file separate. This is equivalent to having a subject_id, if there is one .csv file per participant.

# %%
# Fetch all the files in the 'data' folder that end in .csv
raw_data <- list.files(path = 'data', pattern = ".csv$", full.names = TRUE) %>%

  # Map the read_csv function to all of them, skipping the first 2 rows and creating a new id column called 'id' so that each file gets its own id
  # col_types = cols() just makes explicit that you want tidyverse to do its best to guess the type of each column (string, numeric, etc.)
  map_dfr(read_csv, col_types = cols(), skip = 2, .id = 'id')

# %% [markdown]
# #### Exercise 15
# Tidy the dataset exactly as we did for subject 1, while keeping the education-level information for each subject. Store it as `tidy_data`.
#
# Hint: **group** the tibble before calling `first(response)`), then follow the same steps as before to obtain a tidy dataset. Use `ungroup()` to return to the tibble to the ungrouped state. In fact, in most of the exercises that follow, you will need to use grouping wisely.
#
# ```R
# full_data <- raw_data %>%
#     mutate(education_level = first(response), .by = id) %>%
#     ...
# ```

# %%
# old version which uses group and ungroup
raw_data %>%
    group_by(id) %>%
    mutate(education_level = first(response)) %>%
    ungroup() %>%
    select(id, response, education_level) %>%
    head()
# Out:
#   id response                    education_level
# 1 1  College or Technical School College or Technical School
# 2 1  j                           College or Technical School
# 3 1  f                           College or Technical School
# 4 1  j                           College or Technical School
# 5 1  j                           College or Technical School
# 6 1  j                           College or Technical School

# %%
# new version which uses group wisely
tidy_data <- raw_data %>%
    mutate(education_level = first(response), .by = id) %>%

    filter(type != "form") %>%

    select(
        id,
        stim1,
        stim2,
        trialType,
        response,
        RT,
        education_level
    ) %>%

    rename(
        stim_left = stim1,
        stim_right = stim2,
        trial_type = trialType,
        rt = RT
    ) %>%


    mutate(
        correct_side = ifelse(
            str_detect(stim_left, "Small"),
            "left",
            "right"
        ),

        correct_key = ifelse(
            correct_side == "left",
            "f",
            "j"
        ),

        correct = ifelse(
            response == correct_key,
            1,
            0
        )
    )
head(tidy_data)
# Out:
#   id stim_left      stim_right     trial_type  response rt
# 1 1  croissantLarge breadSmall     incongruent j         729
# 2 1  lampSmall      shelfLarge     congruent   f         625
# 3 1  schoolbusLarge bikeSmall      congruent   j        1477
# 4 1  orangeLarge    raspberrySmall congruent   j         793
# 5 1  hammerLarge    ladderSmall    incongruent j         900
# 6 1  wheelSmall     coinLarge      incongruent f         699
#   education_level             correct_side correct_key correct
# 1 College or Technical School right        j           1
# 2 College or Technical School left         f           1
# 3 College or Technical School right        j           1
# 4 College or Technical School right        j           1
# 5 College or Technical School right        j           1
# 6 College or Technical School left         f           1

# %% [markdown]
# #### Exercise 16
# Trials where the responses were too slow or too fast should be excluded from the analysis. (Why?)
# Exclude the trials where the response is below 200 ms or higher than 1,500 ms. How many trials were excluded?

# %%
filtered_data <- tidy_data %>%
    filter(rt >= 200, rt <= 1500)
head(filtered_data)
# Out:
#   id stim_left      stim_right     trial_type  response rt
# 1 1  croissantLarge breadSmall     incongruent j         729
# 2 1  lampSmall      shelfLarge     congruent   f         625
# 3 1  schoolbusLarge bikeSmall      congruent   j        1477
# 4 1  orangeLarge    raspberrySmall congruent   j         793
# 5 1  hammerLarge    ladderSmall    incongruent j         900
# 6 1  wheelSmall     coinLarge      incongruent f         699
#   education_level             correct_side correct_key correct
# 1 College or Technical School right        j           1
# 2 College or Technical School left         f           1
# 3 College or Technical School right        j           1
# 4 College or Technical School right        j           1
# 5 College or Technical School right        j           1
# 6 College or Technical School left         f           1

# %%
nrow(tidy_data) - nrow(filtered_data)
# Out:
# [1] 284

# %% [markdown]
# #### Exercise 17
# Exclude participants who didn't achieve 93% overall accuracy.
# How many subjects were excluded?

# %%
participant_accuracy <- filtered_data %>%
    summarize(accuracy = mean(correct), .by = id)
participant_accuracy
# Out:
#    id accuracy
# 1  1  0.9831933
# 2  2  0.9583333
# 3  3  0.9572650
# 4  4  0.9250000
# 5  5  0.9473684
# 6  6  0.9594595
# 7  7  0.9885714
# 8  8  0.9620253
# 9  9  0.9937888
# 10 10 0.9591837
# 11 11 0.9409283
# 12 12 0.9811321

# %%
good_participants <- participant_accuracy %>%
    filter(accuracy >= 0.93)
filtered_id <- filtered_data %>%
    filter(id %in% good_participants$id)

head(filtered_id)

n_distinct(filtered_data$id)
n_distinct(filtered_id$id)
# Out:
#   id stim_left      stim_right     trial_type  response rt
# 1 1  croissantLarge breadSmall     incongruent j         729
# 2 1  lampSmall      shelfLarge     congruent   f         625
# 3 1  schoolbusLarge bikeSmall      congruent   j        1477
# 4 1  orangeLarge    raspberrySmall congruent   j         793
# 5 1  hammerLarge    ladderSmall    incongruent j         900
# 6 1  wheelSmall     coinLarge      incongruent f         699
#   education_level             correct_side correct_key correct
# 1 College or Technical School right        j           1
# 2 College or Technical School left         f           1
# 3 College or Technical School right        j           1
# 4 College or Technical School right        j           1
# 5 College or Technical School right        j           1
# 6 College or Technical School left         f           1
# [1] 12
# [1] 11

# %% [markdown]
# #### Exercise 18
# Summarize the response-time and accuracy measures by trial type to check whether there's a Stroop effect.

# %%
filtered_id %>%
    summarize(mean_rt = mean(rt), accuracy = mean(correct), .by = trial_type)
# Out:
#   trial_type  mean_rt  accuracy
# 1 incongruent 814.4211 0.935289
# 2 congruent   707.7510 0.994152

# %% [markdown]
# ## Changing the format of the data: `pivot_wider`, `pivot_longer`

# %% [markdown]
# #### Exercise 19: `pivot_wider`
# Compute the average Stroop effects for each participant. One column should be called `stroop_rt`, the other should be called `stroop_error`. Using `pull`, extract the reaction-time Stroop vector and plot its histogram.

# %%
stroop_data <- filtered_id %>%
    summarize(rt = mean(rt), error = mean(1 - correct), .by = c(id, trial_type))
wide_stroop <- stroop_data %>%
    pivot_wider(names_from = trial_type, values_from = c(rt, error))
wide_stroop <- wide_stroop %>%
    mutate(
        stroop_rt = rt_incongruent - rt_congruent,
        stroop_error = error_incongruent - error_congruent
    )
wide_stroop
# Out:
#    id rt_incongruent rt_congruent error_incongruent error_congruent stroop_rt
# 1  1   683.9576       547.4083    0.03389831        0.000000000     136.54929
# 2  2   738.2407       722.7315    0.07407407        0.009259259      15.50926
# 3  3   804.0000       677.9316    0.08547009        0.000000000     126.06838
# 4  5   862.4248       706.3913    0.10619469        0.000000000     156.03347
# 5  6   835.8704       720.4474    0.05555556        0.026315789     115.42300
# 6  7  1003.2118       909.7333    0.02352941        0.000000000      93.47843
# 7  8   574.1186       532.4790    0.06779661        0.008403361      41.63965
# 8  9  1109.5844      1003.9762    0.01298701        0.000000000     105.60823
# 9  10  982.6264       792.3714    0.07692308        0.009523810     190.25495
# 10 11  624.1949       587.2857    0.11016949        0.008403361      36.90920
# 11 12  944.8113       736.6887    0.03773585        0.000000000     208.12264
#    stroop_error
# 1  0.03389831
# 2  0.06481481
# 3  0.08547009
# 4  0.10619469
# 5  0.02923977
# 6  0.02352941
# 7  0.05939325
# 8  0.01298701
# 9  0.06739927
# 10 0.10176613
# 11 0.03773585

# %%
stroop_rt_vector <- wide_stroop %>%
    pull(stroop_rt)
stroop_rt_vector

hist(stroop_rt_vector)
# Out:
#  [1] 136.54929  15.50926 126.06838 156.03347 115.42300  93.47843  41.63965
#  [8] 105.60823 190.25495  36.90920 208.12264
# Plot with title “Histogram of stroop_rt_vector”

# %% [markdown]
# #### Exercise 20: `pivot_longer`
# Building on the output tibble in Exercise 19, remove all columns except `id`, `stroop_rt`, and `stroop_error`, then gather the two stroop columns into a single column called `measure`. This column should take one of two values for each subject (`stroop_rt` or `stroop_error`), while the `value` column should register the respective participants' stroop effect.

# %%
wide_stroop %>%
    select(id, stroop_rt, stroop_error)
long_stroop <- wide_stroop %>%
    select(id, stroop_rt, stroop_error) %>%
    pivot_longer(
        cols = c(stroop_rt, stroop_error),
        names_to = "measure",
        values_to = "value"
    )
long_stroop
# Out:
#    id stroop_rt stroop_error
# 1  1  136.54929 0.03389831
# 2  2   15.50926 0.06481481
# 3  3  126.06838 0.08547009
# 4  5  156.03347 0.10619469
# 5  6  115.42300 0.02923977
# 6  7   93.47843 0.02352941
# 7  8   41.63965 0.05939325
# 8  9  105.60823 0.01298701
# 9  10 190.25495 0.06739927
# 10 11  36.90920 0.10176613
# 11 12 208.12264 0.03773585
#    id measure      value
# 1  1  stroop_rt    136.54929379
# 2  1  stroop_error   0.03389831
# 3  2  stroop_rt     15.50925926
# 4  2  stroop_error   0.06481481
# 5  3  stroop_rt    126.06837607
# 6  3  stroop_error   0.08547009
# 7  5  stroop_rt    156.03347441
# 8  5  stroop_error   0.10619469
# 9  6  stroop_rt    115.42300195
# 10 6  stroop_error   0.02923977
# 11 7  stroop_rt     93.47843137
# 12 7  stroop_error   0.02352941
# 13 8  stroop_rt     41.63965247
# 14 8  stroop_error   0.05939325
# 15 9  stroop_rt    105.60822511
# 16 9  stroop_error   0.01298701
# 17 10 stroop_rt    190.25494505
# 18 10 stroop_error   0.06739927
# 19 11 stroop_rt     36.90920097
# 20 11 stroop_error   0.10176613
# 21 12 stroop_rt    208.12264151
# 22 12 stroop_error   0.03773585

# %% [markdown]
# ## Data plotting

# %% [markdown]
# ### Rule 1: If your data is in the tidy format (one variable per column, one observation per row), plotting with `ggplot` will be very easy.

# %% [markdown]
# ### Rule 2: No barplots.

# %% [markdown]
# ### One possible way to do it

# %%
average_data <- tidy_data %>% summarize(rt = mean(rt), .by = c(id, trial_type))

ggplot(average_data, aes(x = trial_type, y = rt, fill = trial_type)) +
  geom_boxplot(width = 0.5, alpha = 0.45) +
  geom_point(size = 2) +
  geom_line(aes(group = id), color = 'gray') +
  stat_summary(fun.data = mean_se, linewidth = 2, shape = 21, size = 1.5) +
  labs(title = "Average reaction times by trial type (ms)", x = "Trial type", y = "") +
  theme_minimal() +
  theme(
    legend.position = "none",
    plot.title = element_text(face = "bold", size = 20),
    axis.title = element_text(size = 18),
    axis.text = element_text(size = 16))
# Out:
# plot without title
